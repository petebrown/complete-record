# %% [markdown]
# # `gls_with_games.csv`

# %%
library(tidyverse)

df <- read_csv("../output/gls_with_games.csv", show_col_types = FALSE)

head(df, 5)
# Out:
#   season  game_no player_name    goals_scored game_date  opposition      venue
# 1 1921/22 1       Tom Stuart     1            1921-08-27 Crewe Alexandra H
# 2 1921/22 1       Charles Milnes 1            1921-08-27 Crewe Alexandra H
# 3 1921/22 1       Fred Groves    1            1921-08-27 Crewe Alexandra H
# 4 1921/22 1       John Ford      1            1921-08-27 Crewe Alexandra H
# 5 1921/22 2       John Prentice  1            1921-09-03 Crewe Alexandra A
#   score goals_for goals_against generic_comp    game_type league_tier
# 1 4-1   4         1             Football League League    3
# 2 4-1   4         1             Football League League    3
# 3 4-1   4         1             Football League League    3
# 4 4-1   4         1             Football League League    3
# 5 1-1   1         1             Football League League    3
#   manager
# 1 Bert Cooke
# 2 Bert Cooke
# 3 Bert Cooke
# 4 Bert Cooke
# 5 Bert Cooke

# %% [markdown]
# ### View Goalscorers in wide form

# %%
df %>%
    replace(is.na(.), 0) %>%
    mutate(
        generic_comp = case_when(
            .default = generic_comp,
            generic_comp %in% c("Non-League", "Football League") ~ "League"
        ),
        generic_comp = factor(generic_comp, levels = c(
            "League",
            "FA Cup",
            "League Cup",
            "Associate Members' Cup",
            "Full Members' Cup",
            "Anglo-Italian Cup"
        ))
    ) %>%
    group_by(
        player_name,
        generic_comp
    ) %>%
    summarise(
        total_goals = sum(goals_scored),
        .groups = "drop"
    ) %>%
    pivot_wider(
        names_from = generic_comp,
        values_from = total_goals
    ) %>% rowwise(player_name) %>% mutate(Total = sum(c_across(where(is.numeric)), na.rm = TRUE)) %>%
    arrange(
        desc(Total), desc(League), desc("FA Cup"), desc("League Cup"), desc("Associate Members' Cup"), desc("Full Members' Cup"), desc("Anglo_Italian Cup")
    ) %>%
    ungroup() %>% slice_max(
        order_by = Total,
        n = 20
    )
# Out:
#    player_name     League FA Cup League Cup Associate Members' Cup
# 1  Ian Muir        142    14      6         18
# 2  John Aldridge   138     4     22         NA
# 3  OG              114     4      1         NA
# 4  Bunny Bell      102    11     NA         NA
# 5  Fred Urmson      94    13     NA         NA
# 6  Barry Dyson     100    NA      6         NA
# 7  Harold Atkinson  91    13     NA         NA
# 8  Keith Williams   88     8      1         NA
# 9  James Norwood    88     2     NA         NA
# 10 Ronnie Moore     78     3      4          1
# 11 George Yardley   68     6      7         NA
# 12 Kenny Beamish    64    10      7         NA
# 13 John Manning     71     2      4         NA
# 14 Chris Malkin     62     2      6          2
# 15 Cyril Done       61    14     NA         NA
# 16 Billy Charlton   72     2     NA         NA
# 17 Bill Bainbridge  64     4     NA         NA
# 18 Pongo Waring     65     2     NA         NA
# 19 Kenny Irons      55     3      7         NA
# 20 Farewell Watts   53     7     NA         NA
#    Anglo-Italian Cup Full Members' Cup Total
# 1  NA                NA                180
# 2   3                 7                174
# 3  NA                NA                119
# 4  NA                NA                113
# 5  NA                NA                107
# 6  NA                NA                106
# 7  NA                NA                104
# 8  NA                NA                 97
# 9  NA                NA                 90
# 10 NA                NA                 86
# 11 NA                NA                 81
# 12 NA                NA                 81
# 13 NA                NA                 77
# 14  3                NA                 75
# 15 NA                NA                 75
# 16 NA                NA                 74
# 17 NA                NA                 68
# 18 NA                NA                 67
# 19  2                NA                 67
# 20 NA                NA                 60

# %% [markdown]
# ### Sort seasonal top scorers by proportion of club's league goals they scored

# %%
df %>%
    filter(
        game_type == "League"
    ) %>%
    group_by(
        season,
        player_name
    ) %>%
    summarise(
        goals_scored = sum(goals_scored),
        .groups = "drop"
    ) %>%
    ungroup() %>%
    group_by(
        season
    ) %>%
    mutate(
        pc_gls = round((goals_scored / sum(goals_scored)) * 100, 1)
    ) %>%
    arrange(
        desc(pc_gls),
        season,
        player_name
    ) %>%
    group_by(season) %>%
    slice_max(
        goals_scored,
        n = 3
    ) %>%
    ungroup() %>%
    arrange(
        desc(pc_gls), desc(goals_scored), season, player_name
    ) %>%
    head(10)
# Out:
#    season  player_name     goals_scored pc_gls
# 1  2018/19 James Norwood   29           46.8
# 2  1924/25 Dixie Dean      27           45.8
# 3  1987/88 Ian Muir        27           44.3
# 4  1953/54 Cyril Done      25           42.4
# 5  1995/96 John Aldridge   27           42.2
# 6  1933/34 Bunny Bell      34           40.5
# 7  1991/92 John Aldridge   22           39.3
# 8  1975/76 Ronnie Moore    34           38.2
# 9  1984/85 John Clayton    31           37.3
# 10 1949/50 Bill Bainbridge 19           37.3

# %%
mans_10 <- df %>%
    group_by(manager) %>%
    summarise(
        games = n()
    ) %>%
    filter(games >= 10)

df %>%
    mutate(
        generic_comp = case_when(
            .default = generic_comp,
            generic_comp %in% c("Non-League", "Football League") ~ "League"
        ),
        generic_comp = factor(generic_comp, levels = c(
            "League",
            "FA Cup",
            "League Cup",
            "Associate Members' Cup",
            "Full Members' Cup",
            "Anglo-Italian Cup"
        ))
     ) %>%
    filter(
        generic_comp == "League",
        manager %in% mans_10$manager
    ) %>%
    group_by(
        manager,
        player_name
    ) %>%
    summarise(
        goals_scored = sum(goals_scored),
        .groups = "drop"
    ) %>%
    ungroup() %>%
    group_by(
        manager
    ) %>%
    mutate(
        pc_gls = round((goals_scored / sum(goals_scored)) * 100, 1)
    ) %>%
    arrange(
        desc(pc_gls),
        manager,
        player_name
    ) %>%
    slice_max(
        pc_gls,
        n = 1
    ) %>%
    arrange(desc(pc_gls))
# Out:
#    manager           player_name         goals_scored pc_gls
# 1  Gary Brabin       James Norwood        24          33.3
# 2  John Barnes       Ian Thomas-Moore      3          33.3
# 3  Jack Carr         Bunny Bell           33          28.9
# 4  Keith Hill        James Vaughan        11          28.9
# 5  Bill Ridding      Billy Eden            4          28.6
# 6  Rob Edwards       Abdulai Bell-Baggie   3          27.3
# 7  Rob Edwards       Cole Stockton         3          27.3
# 8  Frank Worthington Ian Muir             29          26.6
# 9  Ian Dawes         James Vaughan         5          26.3
# 10 Peter Farrell     Keith Williams       67          25.6
# 11 Jim Knowles       Pongo Waring         39          25.0
# 12 Jackie Wright     Kenny Beamish        27          24.3
# 13 Walter Galbraith  Ralph Gubbins        18          24.3
# 14 Dave Watson       Stuart Barlow        14          22.2
# 15 Ray Mathias       Simon Haworth        24          20.0
# 16 Micky Mellon      James Norwood        63          18.9
# 17 Ron Yeats         Paul Crossley        27          16.7
# 18 Ernest Blackburn  Harold Atkinson      90          16.3
# 19 Dave Russell      Barry Dyson         100          16.2
# 20 Mickey Adams      Max Power             5          16.1
# 21 Mickey Adams      Rory Donnelly         5          16.1
# 22 Brian Little      Iain Hume            26          15.4
# 23 Les Parry         Ian Thomas-Moore     17          14.7
# 24 John King         John Aldridge       112          12.2
# 25 Noel Kelly        Kenny McDevitt       14          11.0
# 26 Bryan Hamilton    John Kerr            26          10.7
# 27 Ronnie Moore      Chris Greenacre      30           9.8
# 28 John Aldridge     Kenny Irons          27           9.7
# 29 Bert Cooke        Fred Urmson          81           7.5
